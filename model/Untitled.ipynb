# %%
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans

import os
import glob
import sys
os.chdir("../data")
sys.path.append('home/sein/ksc_model/data/A-1/configs/A-1')
dir_list = glob.glob('A-1/configs/A-1/*.cnf')
df = pd.read_csv('A-1/result/external_metrics.csv')
tplt_df = df[['tps','latency_READ']]

# %%
plt.scatter(df['tps'],df['latency_READ'])
plt.xlabel('tps')
plt.ylabel('latency')
#plt.show()
# Out:
# Text(0, 0.5, 'latency')

# %%
from sklearn.preprocessing import MinMaxScaler

#데이터 전처리 MINMAX
scaler = MinMaxScaler()
data_scale = scaler.fit_transform(tplt_df)

k = 4

model = KMeans(n_clusters = k, random_state = 10)
model.fit(data_scale)
tplt_df['cluster'] = model.fit_predict(data_scale)
tplt_df.to_csv("clustering2.csv")
# df['cluster'] = model.fit_predict(data_scale)
# df.to_csv("clustering.csv")

for i in range(k):
    plt.scatter(df.loc[tplt_df['cluster'] == i, 'tps'], df.loc[tplt_df['cluster']==i,'latency_READ'], 
                label = 'cluster' + str(i))

plt.legend()
plt.title('K = %d results'%k)
plt.xlabel('tps')
plt.ylabel('latency')
plt.show()
# Out:
# /home/sein/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
tplt_df['cluster'] = model.fit_predict(data_scale)
tplt_df.to_csv("clustering2.csv")
# Out:
# /home/sein/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
clus=pd.read_csv("clustering2.csv")
one_hot = pd.get_dummies(clus, columns=['cluster'])
print(one_hot)
# Out:
#      Unnamed: 0      tps  latency_READ  cluster_0  cluster_1  cluster_2  \
# 0             0  87624.7         305.0          0          1          0
# 1             1  86652.8         339.0          0          1          0
# 2             2  86010.4         431.0          0          1          0
# 3             3  79557.0         362.0          1          0          0
# 4             4  83238.3         398.0          1          0          0
# ..          ...      ...           ...        ...        ...        ...
# 995         995  84583.0         328.0          0          1          0
# 996         996  92383.8         309.0          0          1          0
# 997         997  88124.3         379.0          0          1          0
# 998         998  79968.6         363.0          1          0          0
# 999         999  81131.2         297.0          1          0          0
#
#      cluster_3
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 995          0
# 996          0
# 997          0
# 998          0
# 999          0
#
# [1000 rows x 7 columns]

# %%
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans


import os
import glob
import sys

wk = 'B-1'

os.chdir("../data")
sys.path.append(f'home/sein/ksc_model/data/{wk}/b/configs')
dir_list = glob.glob(f'{wk}/b/configs/*.cnf')
df = pd.read_csv(f'{wk}/b/results/{wk}/external_metrics.csv')
tplt_df = df[['tps','latency_READ']]

# %%
plt.scatter(df['tps'], df['latency_READ'])
plt.xlabel('tps')
plt.ylabel('latency')
#plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data_scale = scaler.fit_transform(tplt_df)

k = 4

model = KMeans(n_clusters = k, random_state = 10)
model.fit(data_scale)
df['cluster'] = model.fit_predict(data_scale)

for i in range(k):
    plt.scatter(df.loc[df['cluster'] == i, 'tps'], df.loc[df['cluster']==i,'latency_READ'], 
                label = 'cluster' + str(i))

plt.legend()
plt.title('K = %d results'%k)
plt.xlabel('tps')
plt.ylabel('latency')
plt.show()

# %%
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans


import os
import glob
import sys

wk = 'C-1'

os.chdir("../data")
sys.path.append(f'home/sein/ksc_model/data/{wk}/c/configs')
dir_list = glob.glob(f'{wk}/c/configs/*.cnf')
df = pd.read_csv(f'{wk}/c/results/{wk}/external_metrics.csv')
tplt_df = df[['tps','latency_READ']]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data_scale = scaler.fit_transform(tplt_df)

k = 4

model = KMeans(n_clusters = k, random_state = 10)
model.fit(data_scale)
df['cluster'] = model.fit_predict(data_scale)

for i in range(k):
    plt.scatter(df.loc[df['cluster'] == i, 'tps'], df.loc[df['cluster']==i,'latency_READ'], 
                label = 'cluster' + str(i))

plt.legend()
plt.title('K = %d results'%k)
plt.xlabel('tps')
plt.ylabel('latency')
plt.show()

# %%
df['cluster'] = model.fit_predict(data_scale)
df.to_csv("clustering2.csv")

tplt_df['cluster'] = model.fit_predict(data_scale)
df.to_csv("clustering2.csv")

# %%
plt.scatter(df['tps'], df['latency_READ'])
plt.xlabel('tps')
plt.ylabel('latency')
plt.show()
